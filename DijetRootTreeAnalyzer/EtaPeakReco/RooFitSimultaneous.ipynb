# %% [markdown]
# from https://nbviewer.jupyter.org/url/root.cern/doc/master/notebooks/rf102_dataimport.py.nbconvert.ipynb

# %%
import ROOT
from array import array
from ROOT import gROOT 
import numpy as np
import os
# Out:
# Welcome to JupyROOT 6.18/04

# %% [markdown]
# ## Trying Simultaneous fit
# https://root.cern.ch/doc/master/rf501__simultaneouspdf_8py.html

# %%
dgq = 'dataRun2'
# dgq = 'gjets'
ee = 'e30_60'

# %%
if "data" in dgq:
    if(not os.path.exists("mypow_cxx.so")):
        ROOT.RooClassFactory.makePdf(
         "mypow", "x,p0,p1", "", "p0*TMath::Exp(p1*x)") #Declare function
    ROOT.gROOT.ProcessLineSync(".x mypow.cxx+") # Compile it for Roofit
# Out:
# (mypow) An instance of mypow.

# %%
binw = 0.025

if 'data' in dgq:
    rlow =  0.375 #- 1*binw 
    rhigh = 0.725 #- 1*binw
else:
    rlow = 0.375
    rhigh = 0.725-0.05
    
#0.4, 0.68 for 30-60 data and gjets
#0.35, 0.7
# rlow = 0.4
# rhigh = 0.7
helpme = 0.02

# %%
# inFile = ROOT.TFile("./{}Out_{}.root".format(dgq, ee), "read")
if("data" in dgq):
    inFile = ROOT.TFile("./NoTrigOutFiles/{}Out_{}.root".format(dgq, ee), "read")
elif(dgq=="gjets"):
    #inFile = ROOT.TFile("./GJetsFiles/gjetsOut_e30_60_2016.root","read")
    inFile = ROOT.TFile("./GJetsFiles/gjetsOut_m_Run2.root","read")

    
# hist_p = inFile.Get("mass_pp")
# hist_f = inFile.Get("mass_ff")
if("data" in dgq):
    hist_p = inFile.Get("mass_pp")
    hist_f = inFile.Get("mass_ff")
else:
    hist_p = inFile.Get("mass")
    hist_f = inFile.Get("fail")

# %%
c1 = ROOT.TCanvas("c", "c", 800, 800)
c1.cd()
hist_f.Draw("hist")
# gROOT.GetListOfCanvases().Draw()

# %%
# passhist = ROOT.TH1F("pass", "diphoton mass ; mass (GeV) ; ", hist_p.GetNbinsX(), hist_p.GetBinCenter(1), hist_p.GetBinCenter(hist_p.GetNbinsX() + 1) )
# failhist = ROOT.TH1F("fail", "diphoton mass ; mass (GeV) ; ", hist_f.GetNbinsX(), hist_f.GetBinCenter(1), hist_f.GetBinCenter(hist_f.GetNbinsX() + 1) )

passhist = ROOT.TH1F("pass", "diphoton mass ; mass (GeV) ; ", hist_p.GetNbinsX(), hist_p.GetBinLowEdge(1), hist_p.GetBinLowEdge(hist_p.GetNbinsX() + 1) )
failhist = ROOT.TH1F("fail", "diphoton mass ; mass (GeV) ; ", hist_f.GetNbinsX(), hist_f.GetBinLowEdge(1), hist_f.GetBinLowEdge(hist_f.GetNbinsX() + 1) )


#Pass
for i in range(1, hist_p.GetNbinsX()+1):
    if(hist_p.GetBinContent(i) < 0): continue
    if( hist_p.GetBinCenter(i) >= rlow-helpme and hist_p.GetBinCenter(i) < rhigh):
        passhist.SetBinContent(i, hist_p.GetBinContent(i))

#Fail
for i in range(1, hist_f.GetNbinsX()+1):
    if(hist_f.GetBinContent(i) < 0): continue
    if( hist_f.GetBinCenter(i) >= rlow-helpme and hist_f.GetBinCenter(i) < rhigh):
        failhist.SetBinContent(i, hist_f.GetBinContent(i))

        
# passhist.GetXaxis().SetRangeUser(rlow, rhigh)
# failhist.GetXaxis().SetRangeUser(rlow, rhigh)

# %%
c1 = ROOT.TCanvas("c", "c", 400, 400)
c1.cd()
# failhist.Draw("SAME")
passhist.Draw("SAME")
# gROOT.GetListOfCanvases().Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
passhist.Integral()
# Out:
# 19442781.0

# %%
x = ROOT.RooRealVar("x", "x", rlow+0.02, rhigh)

# %%
data_pass = ROOT.RooDataHist("dh","dh",ROOT.RooArgList(x), passhist)
data_fail = ROOT.RooDataHist("df","df",ROOT.RooArgList(x), failhist)
# Out:
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(dh): fit range of variable x expanded to nearest bin boundaries: [0.395,0.725] --> [0.375,0.725]

# %%
#Passing PDF

ss = 0.0401
se = 2.0e-05
sw = 10000

#Signal PDF
# mean_p = ROOT.RooRealVar("mean_p", "mean_p", 0.548, 0.5, 0.6)
mean_p = ROOT.RooRealVar("mean_p", "mean_p", 0.55, 0.53, 0.6)
# sigma_p = ROOT.RooRealVar("sigma_p", "sigma_p", 4.0e-02, 4.0e-02 - 100*2.0e-04, 4.0e-02 + 100*2.0e-04)
sigma_p = ROOT.RooRealVar("sigma_p", "sigma_p", ss, ss-sw*se, ss+sw*se)

gx_p = ROOT.RooGaussian("gauss_pass", "gauss_pass", x, mean_p, sigma_p)

#Background PDF
#Power 
if 'data' in dgq:
    a0_p = ROOT.RooRealVar("a0_p", "a0_p", 10, -100, 100)
    a1_p = ROOT.RooRealVar("a1_p", "a1_p", 1, -10, 10)

    px_p = ROOT.mypow("px_p", "px_p", x, a0_p, a1_p)
    
else:

    # Argus
    m_p = ROOT.RooRealVar("m_p", "m_p", 10, 0, 100)
    m0_p = ROOT.RooRealVar("m0_p", "m0_p", -1, -100, 10)
    c_p = ROOT.RooRealVar("c_p", "c_p", 1, -100, 100)
    px_p = ROOT.RooArgusBG("px_p", "px_p", x, m_p, m0_p, c_p)


# Construct composite pdf
f_p = ROOT.RooRealVar("f_p", "f_p", 0.2, 0.0, 1.0)
model_p = ROOT.RooAddPdf("model_p", "model_p", ROOT.RooArgList(gx_p, px_p), ROOT.RooArgList(f_p))

# model_p.fitTo(data_pass)

a_p = ROOT.RooRealVar("a_p","a_p", passhist.Integral())
p_ext = ROOT.RooExtendPdf("modelp","modelp",model_p,a_p)

# p_ext.fitTo(data_pass)

# %%
#Background
# #Power 
#Power 
if 'data' in dgq:
    a0_f = ROOT.RooRealVar("a0_f", "a0_f", 10, -100, 100)
    a1_f = ROOT.RooRealVar("a1_f", "a1_f", 1, -10, 10)

    px_f = ROOT.mypow("px_f", "px_f", x, a0_f, a1_f)
    
else:
   
    # Argus
    m_f = ROOT.RooRealVar("m_f", "m_f", 10, 0, 100)
    m0_f = ROOT.RooRealVar("m0_f", "m0_f", -1, -100, 100)
    c_f = ROOT.RooRealVar("c_f", "c_f", 1, -100, 100)
    px_f = ROOT.RooArgusBG("px_f", "px_f", x, m_f, m0_f, c_f)


# #Polynomial
# p = ROOT.RooRealVar("coeff","coeff",0,-10,10)
# px_f = ROOT.RooPolynomial("poly","poly",x,p,lowestorder=3)

# Construct composite pdf
f_f = ROOT.RooRealVar("f_f", "f_f", 0.2, 0.0, 1.0)
model_f = ROOT.RooAddPdf("model_f", "model_f", ROOT.RooArgList(gx_p, px_f), ROOT.RooArgList(f_f))

a_f = ROOT.RooRealVar("a_f","a_f", failhist.Integral())
f_ext = ROOT.RooExtendPdf("modelf","modelf",model_f,a_f)

# %%
# Define category to distinguish physics and control samples events
sample = ROOT.RooCategory("sample", "sample")
sample.defineType("pass")
sample.defineType("fail")
# Out:
# False

# %%
# Construct combined dataset in (x,sample)
combData = ROOT.RooDataHist(
    "combData",
    "combined data",
    ROOT.RooArgList(x),
    ROOT.RooFit.Index(sample),
    ROOT.RooFit.Import("pass", passhist),
    ROOT.RooFit.Import("fail", failhist),
)

# %%
# Construct a simultaneous pdf using category sample as index
simPdf = ROOT.RooSimultaneous("simPdf", "simultaneous pdf", sample)

# Associate model with the physics state and model_ctl with the control
# state
# simPdf.addPdf(model_p, "pass")
# simPdf.addPdf(model_f, "fail")
simPdf.addPdf(p_ext, "pass")
simPdf.addPdf(f_ext, "fail")
# Out:
# False

# %%
abc = simPdf.fitTo(combData, ROOT.RooFit.Save())
# Out:
# [#1] INFO:Minization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooAbsTestStatistic::initSimMode: creating slave calculator #0 for state pass (14 dataset entries)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_p_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# RooAbsTestStatistic::initSimMode: creating slave calculator #1 for state fail (14 dataset entries)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_f_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:Fitting -- RooAbsTestStatistic::initSimMode: created 2 slave calculators.
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_p_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_p_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss_pass,px_p)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_f_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_f_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:Minization --  The following expressions will be evaluated in cache-and-track mode: (gauss_pass,px_f)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a0_f         1.00000e+01  2.00000e+01   -1.00000e+02  1.00000e+02
#      2 a0_p         1.00000e+01  2.00000e+01   -1.00000e+02  1.00000e+02
#      3 a1_f         1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
#      4 a1_p         1.00000e+00  2.00000e+00   -1.00000e+01  1.00000e+01
#      5 f_f          2.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      6 f_p          2.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 mean_p       5.50000e-01  7.00000e-03    5.30000e-01  6.00000e-01
#      8 sigma_p      4.01000e-02  4.00000e-02   -1.59900e-01  2.40100e-01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.09102e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-10.2084, a0_p=10, a1_f=1, a1_p=1, f_f=0.2, f_p=0.2, mean_p=0.55, sigma_p=0.0401
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-15.040033), forcing value to zero @ x=x=0.3875, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-14.853203), forcing value to zero @ x=x=0.375, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-21.077698), forcing value to zero @ x=x=0.725, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-17.693822), forcing value to zero @ x=x=0.55, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-16.211414), forcing value to zero @ x=x=0.4625, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-19.311785), forcing value to zero @ x=x=0.6375, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-15.517455), forcing value to zero @ x=x=0.41875, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-16.936406), forcing value to zero @ x=x=0.50625, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-18.485110), forcing value to zero @ x=x=0.59375, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-20.175430), forcing value to zero @ x=x=0.68125, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-15.181697), forcing value to zero @ x=x=0.396875, p0=a0_f=-10.2084, p1=a1_f=1
#      p.d.f value is less than zero (-15.860639), forcing value to zero @ x=x=0.440625, p0=a0_f=-10.2084, p1=a1_f=1
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.09102e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=10, a0_p=-10.2084, a1_f=1, a1_p=1, f_f=0.2, f_p=0.2, mean_p=0.55, sigma_p=0.0401
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-15.040033), forcing value to zero @ x=x=0.3875, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-14.853203), forcing value to zero @ x=x=0.375, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-21.077698), forcing value to zero @ x=x=0.725, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-17.693822), forcing value to zero @ x=x=0.55, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-16.211414), forcing value to zero @ x=x=0.4625, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-19.311785), forcing value to zero @ x=x=0.6375, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-15.517455), forcing value to zero @ x=x=0.41875, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-16.936406), forcing value to zero @ x=x=0.50625, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-18.485110), forcing value to zero @ x=x=0.59375, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-20.175430), forcing value to zero @ x=x=0.68125, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-15.181697), forcing value to zero @ x=x=0.396875, p0=a0_p=-10.2084, p1=a1_p=1
#      p.d.f value is less than zero (-15.860639), forcing value to zero @ x=x=0.440625, p0=a0_p=-10.2084, p1=a1_p=1
#     ... (remaining 35 messages suppressed)
#
#  FCN=-3.09102e+09 FROM MIGRAD    STATUS=INITIATE       32 CALLS          33 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a0_f         1.00000e+01   2.00000e+01   2.02430e-01  -2.46999e+00
#    2  a0_p         1.00000e+01   2.00000e+01   2.02430e-01  -2.46999e+00
#    3  a1_f         1.00000e+00   2.00000e+00   2.02430e-01   4.15552e+07
#    4  a1_p         1.00000e+00   2.00000e+00   2.02430e-01   4.89046e+06
#    5  f_f          2.00000e-01   1.00000e-01   2.57889e-01   1.58700e+07
#    6  f_p          2.00000e-01   1.00000e-01   2.57889e-01   1.23788e+06
#    7  mean_p       5.50000e-01   7.00000e-03   2.24553e-01   3.00679e+06
#    8  sigma_p      4.01000e-02   4.00000e-02   2.01358e-01  -3.26047e+07
#                                ERR DEF= 0.5
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-30.2729, a0_p=19.126, a1_f=-2.08548, a1_p=-2.2251, f_f=0.0830047, f_p=0.109489, mean_p=0.538988, sigma_p=0.0669743
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-13.492425), forcing value to zero @ x=x=0.3875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-13.848778), forcing value to zero @ x=x=0.375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-6.674391), forcing value to zero @ x=x=0.725, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-9.614165), forcing value to zero @ x=x=0.55, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-11.538823), forcing value to zero @ x=x=0.4625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-8.010537), forcing value to zero @ x=x=0.6375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-12.641147), forcing value to zero @ x=x=0.41875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-10.532623), forcing value to zero @ x=x=0.50625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-8.775797), forcing value to zero @ x=x=0.59375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-7.312008), forcing value to zero @ x=x=0.68125, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-13.231192), forcing value to zero @ x=x=0.396875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-12.077415), forcing value to zero @ x=x=0.440625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-30.2729, a0_p=19.126, a1_f=-2.08548, a1_p=-2.2251, f_f=0.0830047, f_p=0.109489, mean_p=0.538988, sigma_p=0.0669743
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-13.492425), forcing value to zero @ x=x=0.3875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-13.848778), forcing value to zero @ x=x=0.375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-6.674391), forcing value to zero @ x=x=0.725, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-9.614165), forcing value to zero @ x=x=0.55, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-11.538823), forcing value to zero @ x=x=0.4625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-8.010537), forcing value to zero @ x=x=0.6375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-12.641147), forcing value to zero @ x=x=0.41875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-10.532623), forcing value to zero @ x=x=0.50625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-8.775797), forcing value to zero @ x=x=0.59375, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-7.312008), forcing value to zero @ x=x=0.68125, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-13.231192), forcing value to zero @ x=x=0.396875, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#      p.d.f value is less than zero (-12.077415), forcing value to zero @ x=x=0.440625, p0=a0_f=-30.2729, p1=a1_f=-2.08548
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.126, a0_p=-30.2729, a1_f=-2.08548, a1_p=-2.2251, f_f=0.0830047, f_p=0.109489, mean_p=0.538988, sigma_p=0.0669743
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.781833), forcing value to zero @ x=x=0.3875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-13.142335), forcing value to zero @ x=x=0.375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-6.031839), forcing value to zero @ x=x=0.725, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-8.903508), forcing value to zero @ x=x=0.55, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-10.817249), forcing value to zero @ x=x=0.4625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-7.328337), forcing value to zero @ x=x=0.6375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-11.923251), forcing value to zero @ x=x=0.41875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-9.813840), forcing value to zero @ x=x=0.50625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-8.077618), forcing value to zero @ x=x=0.59375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-6.648560), forcing value to zero @ x=x=0.68125, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-12.517961), forcing value to zero @ x=x=0.396875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-11.356794), forcing value to zero @ x=x=0.440625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.126, a0_p=-30.2729, a1_f=-2.08548, a1_p=-2.2251, f_f=0.0830047, f_p=0.109489, mean_p=0.538988, sigma_p=0.0669743
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.781833), forcing value to zero @ x=x=0.3875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-13.142335), forcing value to zero @ x=x=0.375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-6.031839), forcing value to zero @ x=x=0.725, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-8.903508), forcing value to zero @ x=x=0.55, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-10.817249), forcing value to zero @ x=x=0.4625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-7.328337), forcing value to zero @ x=x=0.6375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-11.923251), forcing value to zero @ x=x=0.41875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-9.813840), forcing value to zero @ x=x=0.50625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-8.077618), forcing value to zero @ x=x=0.59375, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-6.648560), forcing value to zero @ x=x=0.68125, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-12.517961), forcing value to zero @ x=x=0.396875, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#      p.d.f value is less than zero (-11.356794), forcing value to zero @ x=x=0.440625, p0=a0_p=-30.2729, p1=a1_p=-2.2251
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7491, a0_p=19.6647, a1_f=-2.1486, a1_p=-2.29092, f_f=0.0810467, f_p=0.107851, mean_p=0.539915, sigma_p=0.0675302
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-12.938599), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-13.290806), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-6.265526), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-9.125453), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-11.012930), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-7.561465), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-12.098377), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-10.024868), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-8.306732), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-6.883063), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-12.680583), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#      p.d.f value is less than zero (-11.542901), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7491, p1=a1_f=-2.1486
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6647, a0_p=-29.7491, a1_f=-2.1486, a1_p=-2.29092, f_f=0.0810467, f_p=0.107851, mean_p=0.539915, sigma_p=0.0675302
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.244380), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-12.600084), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-5.651282), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-8.438402), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-10.311381), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-6.905634), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-11.398433), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-9.328000), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-7.633644), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-6.247054), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-11.984207), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#      p.d.f value is less than zero (-10.841291), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7491, p1=a1_p=-2.29092
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7306, a0_p=19.6837, a1_f=-1.84453, a1_p=-2.01683, f_f=0.0643297, f_p=0.11076, mean_p=0.541227, sigma_p=0.0704645
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.547512), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-14.886825), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-7.805985), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-10.779904), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-12.668013), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-9.173209), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-13.732680), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-11.685887), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-9.944160), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-8.462029), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-14.298112), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-13.189608), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7306, a0_p=19.6837, a1_f=-1.84453, a1_p=-2.01683, f_f=0.0643297, f_p=0.11076, mean_p=0.541227, sigma_p=0.0704645
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.547512), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-14.886825), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-7.805985), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-10.779904), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-12.668013), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-9.173209), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-13.732680), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-11.685887), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-9.944160), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-8.462029), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-14.298112), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#      p.d.f value is less than zero (-13.189608), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7306, p1=a1_f=-1.84453
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6837, a0_p=-29.7306, a1_f=-1.84453, a1_p=-2.01683, f_f=0.0643297, f_p=0.11076, mean_p=0.541227, sigma_p=0.0704645
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-13.607972), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-13.955394), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-6.889352), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-9.805286), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-11.697719), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-8.219006), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-12.776787), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-10.709784), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-8.977177), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-7.524867), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-13.353093), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-12.225353), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6837, a0_p=-29.7306, a1_f=-1.84453, a1_p=-2.01683, f_f=0.0643297, f_p=0.11076, mean_p=0.541227, sigma_p=0.0704645
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-13.607972), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-13.955394), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-6.889352), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-9.805286), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-11.697719), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-8.219006), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-12.776787), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-10.709784), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-8.977177), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-7.524867), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-13.353093), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#      p.d.f value is less than zero (-12.225353), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7306, p1=a1_p=-2.01683
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7169, a0_p=19.6977, a1_f=-1.81764, a1_p=-1.99288, f_f=0.0626749, f_p=0.111059, mean_p=0.541359, sigma_p=0.0707697
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.693143), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-15.030800), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-7.956010), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-10.935502), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-12.820660), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-9.327538), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-13.881815), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-11.840623), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-10.099570), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-8.614522), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-14.444888), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#      p.d.f value is less than zero (-13.340691), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7169, p1=a1_f=-1.81764
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6977, a0_p=-29.7169, a1_f=-1.81764, a1_p=-1.99288, f_f=0.0626749, f_p=0.111059, mean_p=0.541359, sigma_p=0.0707697
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-13.728520), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-14.074807), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-7.006783), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-9.930716), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-11.822559), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-8.341605), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-12.899622), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-10.835427), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-9.101544), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-7.645117), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-13.474408), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#      p.d.f value is less than zero (-12.349354), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7169, p1=a1_p=-1.99288
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7162, a0_p=19.6984, a1_f=-1.99535, a1_p=-2.1806, f_f=0.0288268, f_p=0.124918, mean_p=0.535861, sigma_p=0.0759806
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-13.715083), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-14.061465), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-6.994094), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-9.917016), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-11.808800), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-8.328297), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-12.886001), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-10.821648), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-9.088006), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-7.632096), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-13.460908), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-12.335648), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.7162, a0_p=19.6984, a1_f=-1.99535, a1_p=-2.1806, f_f=0.0288268, f_p=0.124918, mean_p=0.535861, sigma_p=0.0759806
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-13.715083), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-14.061465), forcing value to zero @ x=x=0.375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-6.994094), forcing value to zero @ x=x=0.725, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-9.917016), forcing value to zero @ x=x=0.55, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-11.808800), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-8.328297), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-12.886001), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-10.821648), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-9.088006), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-7.632096), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-13.460908), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#      p.d.f value is less than zero (-12.335648), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.7162, p1=a1_f=-1.99535
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6984, a0_p=-29.7162, a1_f=-1.99535, a1_p=-2.1806, f_f=0.0288268, f_p=0.124918, mean_p=0.535861, sigma_p=0.0759806
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.765058), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-13.117786), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-6.115089), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-8.956362), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-10.839172), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-7.400605), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-11.924175), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-9.852896), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-8.141406), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-6.727210), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-12.506749), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-11.368737), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.6984, a0_p=-29.7162, a1_f=-1.99535, a1_p=-2.1806, f_f=0.0288268, f_p=0.124918, mean_p=0.535861, sigma_p=0.0759806
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.765058), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-13.117786), forcing value to zero @ x=x=0.375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-6.115089), forcing value to zero @ x=x=0.725, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-8.956362), forcing value to zero @ x=x=0.55, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-10.839172), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-7.400605), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-11.924175), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-9.852896), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-8.141406), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-6.727210), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-12.506749), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#      p.d.f value is less than zero (-11.368737), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.7162, p1=a1_p=-2.1806
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.6893, a0_p=19.7261, a1_f=-1.91089, a1_p=-2.14562, f_f=0.0186681, f_p=0.131229, mean_p=0.534901, sigma_p=0.0782271
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.158536), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-14.500799), forcing value to zero @ x=x=0.375, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-7.429015), forcing value to zero @ x=x=0.725, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-10.379145), forcing value to zero @ x=x=0.55, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-12.268085), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-8.781049), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-13.337805), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-11.284158), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-9.546716), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-8.076791), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-13.907150), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#      p.d.f value is less than zero (-12.791768), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.6893, p1=a1_f=-1.91089
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.7261, a0_p=-29.6893, a1_f=-1.91089, a1_p=-2.14562, f_f=0.0186681, f_p=0.131229, mean_p=0.534901, sigma_p=0.0782271
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-12.927534), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-13.278945), forcing value to zero @ x=x=0.375, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-6.266471), forcing value to zero @ x=x=0.725, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-9.122068), forcing value to zero @ x=x=0.55, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-11.005973), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-7.560634), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-12.089157), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-10.019842), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-8.304734), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-6.883204), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-12.670093), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#      p.d.f value is less than zero (-11.534857), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.6893, p1=a1_p=-2.14562
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.6876, a0_p=19.7278, a1_f=-1.92216, a1_p=-2.10268, f_f=0.0169964, f_p=0.133795, mean_p=0.534594, sigma_p=0.0785307
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.096002), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-14.438789), forcing value to zero @ x=x=0.375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-7.368117), forcing value to zero @ x=x=0.725, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-10.314392), forcing value to zero @ x=x=0.55, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-12.203578), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-8.717663), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-13.274219), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-11.219291), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-9.482478), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-8.014534), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-13.844264), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-12.727646), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-29.6876, a0_p=19.7278, a1_f=-1.92216, a1_p=-2.10268, f_f=0.0169964, f_p=0.133795, mean_p=0.534594, sigma_p=0.0785307
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-14.096002), forcing value to zero @ x=x=0.3875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-14.438789), forcing value to zero @ x=x=0.375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-7.368117), forcing value to zero @ x=x=0.725, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-10.314392), forcing value to zero @ x=x=0.55, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-12.203578), forcing value to zero @ x=x=0.4625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-8.717663), forcing value to zero @ x=x=0.6375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-13.274219), forcing value to zero @ x=x=0.41875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-11.219291), forcing value to zero @ x=x=0.50625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-9.482478), forcing value to zero @ x=x=0.59375, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-8.014534), forcing value to zero @ x=x=0.68125, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-13.844264), forcing value to zero @ x=x=0.396875, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#      p.d.f value is less than zero (-12.727646), forcing value to zero @ x=x=0.440625, p0=a0_f=-29.6876, p1=a1_f=-1.92216
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.7278, a0_p=-29.6876, a1_f=-1.92216, a1_p=-2.10268, f_f=0.0169964, f_p=0.133795, mean_p=0.534594, sigma_p=0.0785307
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-13.143662), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-13.493703), forcing value to zero @ x=x=0.375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-6.464237), forcing value to zero @ x=x=0.725, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-9.339512), forcing value to zero @ x=x=0.55, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-11.226068), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-7.769995), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-12.307771), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-10.239434), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-8.518683), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-7.087107), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-12.887103), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-11.754483), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=19.7278, a0_p=-29.6876, a1_f=-1.92216, a1_p=-2.10268, f_f=0.0169964, f_p=0.133795, mean_p=0.534594, sigma_p=0.0785307
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-13.143662), forcing value to zero @ x=x=0.3875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-13.493703), forcing value to zero @ x=x=0.375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-6.464237), forcing value to zero @ x=x=0.725, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-9.339512), forcing value to zero @ x=x=0.55, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-11.226068), forcing value to zero @ x=x=0.4625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-7.769995), forcing value to zero @ x=x=0.6375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-12.307771), forcing value to zero @ x=x=0.41875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-10.239434), forcing value to zero @ x=x=0.50625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-8.518683), forcing value to zero @ x=x=0.59375, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-7.087107), forcing value to zero @ x=x=0.68125, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-12.887103), forcing value to zero @ x=x=0.396875, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#      p.d.f value is less than zero (-11.754483), forcing value to zero @ x=x=0.440625, p0=a0_p=-29.6876, p1=a1_p=-2.10268
#     ... (remaining 35 messages suppressed)
#
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.1307e+00  2.8853e-11  6.5932e-01  9.3857e-01  1.2760e+00  1.3765e+00  2.0000e+00  2.8804e+00
#  MINUIT WARNING IN MIGRAD
#  ============== MATRIX FORCED POS-DEF BY ADDING 1.133630 TO DIAGONAL.
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# ...
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-5.8206, a0_p=42.7535, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0724703, mean_p=0.537631, sigma_p=0.0396424
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-2.776201), forcing value to zero @ x=x=0.3875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.843298), forcing value to zero @ x=x=0.375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.456867), forcing value to zero @ x=x=0.725, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.035266), forcing value to zero @ x=x=0.55, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.405591), forcing value to zero @ x=x=0.4625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.721950), forcing value to zero @ x=x=0.6375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.615303), forcing value to zero @ x=x=0.41875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.212694), forcing value to zero @ x=x=0.50625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.872065), forcing value to zero @ x=x=0.59375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.583872), forcing value to zero @ x=x=0.68125, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.726919), forcing value to zero @ x=x=0.396875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.508256), forcing value to zero @ x=x=0.440625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=42.7532, a0_p=-5.82031, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0724703, mean_p=0.537631, sigma_p=0.0396424
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-2.605631), forcing value to zero @ x=x=0.3875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.674065), forcing value to zero @ x=x=0.375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.293947), forcing value to zero @ x=x=0.725, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.860134), forcing value to zero @ x=x=0.55, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.230273), forcing value to zero @ x=x=0.4625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.551423), forcing value to zero @ x=x=0.6375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.442109), forcing value to zero @ x=x=0.41875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.036813), forcing value to zero @ x=x=0.50625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.698780), forcing value to zero @ x=x=0.59375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.416848), forcing value to zero @ x=x=0.68125, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.555457), forcing value to zero @ x=x=0.396875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.333789), forcing value to zero @ x=x=0.440625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-5.8206, a0_p=42.7535, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0721593, mean_p=0.537458, sigma_p=0.0396424
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-2.776201), forcing value to zero @ x=x=0.3875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.843298), forcing value to zero @ x=x=0.375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.456867), forcing value to zero @ x=x=0.725, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.035266), forcing value to zero @ x=x=0.55, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.405591), forcing value to zero @ x=x=0.4625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.721950), forcing value to zero @ x=x=0.6375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.615303), forcing value to zero @ x=x=0.41875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.212694), forcing value to zero @ x=x=0.50625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.872065), forcing value to zero @ x=x=0.59375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.583872), forcing value to zero @ x=x=0.68125, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.726919), forcing value to zero @ x=x=0.396875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.508256), forcing value to zero @ x=x=0.440625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=42.7532, a0_p=-5.82031, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0721593, mean_p=0.537458, sigma_p=0.0396424
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-2.605631), forcing value to zero @ x=x=0.3875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.674065), forcing value to zero @ x=x=0.375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.293947), forcing value to zero @ x=x=0.725, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.860134), forcing value to zero @ x=x=0.55, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.230273), forcing value to zero @ x=x=0.4625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.551423), forcing value to zero @ x=x=0.6375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.442109), forcing value to zero @ x=x=0.41875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.036813), forcing value to zero @ x=x=0.50625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.698780), forcing value to zero @ x=x=0.59375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.416848), forcing value to zero @ x=x=0.68125, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.555457), forcing value to zero @ x=x=0.396875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.333789), forcing value to zero @ x=x=0.440625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=-5.8206, a0_p=42.7535, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0721593, mean_p=0.537631, sigma_p=0.0397898
# mypow::px_f[ x=x p0=a0_f p1=a1_f ]
#      p.d.f value is less than zero (-2.776201), forcing value to zero @ x=x=0.3875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.843298), forcing value to zero @ x=x=0.375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.456867), forcing value to zero @ x=x=0.725, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.035266), forcing value to zero @ x=x=0.55, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.405591), forcing value to zero @ x=x=0.4625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.721950), forcing value to zero @ x=x=0.6375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.615303), forcing value to zero @ x=x=0.41875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.212694), forcing value to zero @ x=x=0.50625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.872065), forcing value to zero @ x=x=0.59375, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-1.583872), forcing value to zero @ x=x=0.68125, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.726919), forcing value to zero @ x=x=0.396875, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#      p.d.f value is less than zero (-2.508256), forcing value to zero @ x=x=0.440625, p0=a0_f=-5.8206 +/- 0.105445, p1=a1_f=-1.9105 +/- 0.000814588
#     ... (remaining 35 messages suppressed)
#
# [#0] WARNING:Minization -- RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.05678e+09) to force MIGRAD to back out of this region. Error log follows
# Parameter values: a0_f=42.7532, a0_p=-5.82031, a1_f=-1.9105, a1_p=-2.07401, f_f=0.00639925, f_p=0.0721593, mean_p=0.537631, sigma_p=0.0397898
# mypow::px_p[ x=x p0=a0_p p1=a1_p ]
#      p.d.f value is less than zero (-2.605631), forcing value to zero @ x=x=0.3875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.674065), forcing value to zero @ x=x=0.375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.293947), forcing value to zero @ x=x=0.725, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.860134), forcing value to zero @ x=x=0.55, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.230273), forcing value to zero @ x=x=0.4625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.551423), forcing value to zero @ x=x=0.6375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.442109), forcing value to zero @ x=x=0.41875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.036813), forcing value to zero @ x=x=0.50625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.698780), forcing value to zero @ x=x=0.59375, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-1.416848), forcing value to zero @ x=x=0.68125, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.555457), forcing value to zero @ x=x=0.396875, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#      p.d.f value is less than zero (-2.333789), forcing value to zero @ x=x=0.440625, p0=a0_p=-5.82031 +/- 0.105445, p1=a1_p=-2.07401 +/- 0.00262001
#     ... (remaining 35 messages suppressed)
#
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -2.0146e-06  2.7684e-01  6.5518e-01  9.4228e-01  1.0579e+00  1.3565e+00  1.7113e+00  2.0000e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.002002 TO DIAGONAL.
#  FCN=-3.10273e+09 FROM HESSE     STATUS=NOT POSDEF     61 CALLS        1133 TOTAL
#                      EDM=1.14873e+10    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  a0_f         4.27532e+01   1.05484e-01   5.00000e-01   8.50770e+04
#    2  a0_p         4.27535e+01   1.05483e-01   5.00000e-01   8.50770e+04
#    3  a1_f        -1.91050e+00   8.12253e-04   6.33191e-04  -1.92232e-01
#    4  a1_p        -2.07401e+00   2.64238e-03   3.91415e-04  -2.08917e-01
#    5  f_f          6.39925e-03   6.93589e-05   1.25896e-03  -1.41063e+00
#    6  f_p          7.21593e-02   2.83290e-04   1.20078e-03  -1.02687e+00
#    7  mean_p       5.37631e-01   1.25483e-04   7.98442e-03  -2.24377e+00
#    8  sigma_p      3.96424e-02   1.37996e-04   7.36904e-04  -2.28814e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  8    ERR DEF=0.5
#   1.113e-02  1.110e-02  1.737e-06  1.808e-06  5.183e-08  4.850e-07  1.659e-07  3.331e-07
#   1.110e-02  1.113e-02  1.737e-06  1.808e-06  5.183e-08  4.850e-07  1.659e-07  3.331e-07
#   1.737e-06  1.737e-06  6.598e-07  6.862e-08 -2.944e-09  6.792e-10  9.622e-09 -1.541e-11
#   1.808e-06  1.808e-06  6.862e-08  6.982e-06  8.252e-10 -3.080e-08  1.084e-07 -3.466e-09
#   5.183e-08  5.183e-08 -2.944e-09  8.252e-10  4.811e-09  3.959e-09  6.030e-10  2.745e-09
#   4.850e-07  4.850e-07  6.792e-10 -3.080e-08  3.959e-09  8.025e-08  5.272e-09  2.737e-08
#   1.659e-07  1.659e-07  9.622e-09  1.084e-07  6.030e-10  5.272e-09  1.575e-08  2.891e-09
#   3.331e-07  3.331e-07 -1.541e-11 -3.466e-09  2.745e-09  2.737e-08  2.891e-09  1.904e-08
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7      8
#         1  0.99800   1.000  0.998  0.020  0.006  0.007  0.016  0.013  0.023
#         2  0.99800   0.998  1.000  0.020  0.006  0.007  0.016  0.013  0.023
#         3  0.11298   0.020  0.020  1.000  0.032 -0.052  0.003  0.094 -0.000
#         4  0.33917   0.006  0.006  0.032  1.000  0.005 -0.041  0.327 -0.010
#         5  0.29275   0.007  0.007 -0.052  0.005  1.000  0.202  0.069  0.287
#         6  0.70258   0.016  0.016  0.003 -0.041  0.202  1.000  0.148  0.700
#         7  0.38332   0.013  0.013  0.094  0.327  0.069  0.148  1.000  0.167
#         8  0.71826   0.023  0.023 -0.000 -0.010  0.287  0.700  0.167  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization

# %%
# simPdf.minNll()

# %%
if(dgq=='qcd'):color = 46
if(dgq=='gjets'): color= 30
elif(dgq=='mc'):color = 6
else: color = 4

# %%
frame1 = x.frame(ROOT.RooFit.Title("Pass sample, {}".format(dgq)))

# %%
combData.plotOn(frame1, ROOT.RooFit.Cut("sample==sample::pass"),  ROOT.RooFit.Name("combData"), ROOT.RooFit.DataError(ROOT.RooAbsData.SumW2))
# Out:
# <ROOT.RooPlot object ("frame_x_6af2be0") at 0x6af2be0>
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 1.77114e+07 events out of 1.72328e+08 total events

# %%
sampleSet = ROOT.RooArgSet(sample)

simPdf.plotOn(frame1, ROOT.RooFit.Slice(sample, "pass"), 
              ROOT.RooFit.ProjWData(sampleSet, combData),
              ROOT.RooFit.LineColor(color),
              ROOT.RooFit.Name("simPdf")
             )


simPdf.plotOn(frame1, 
              ROOT.RooFit.Slice(sample, "pass"), 
              ROOT.RooFit.Components("px_p"), 
              ROOT.RooFit.ProjWData(sampleSet, combData), 
              ROOT.RooFit.LineStyle(ROOT.kDashed),
              ROOT.RooFit.LineColor(color)
             )
# Out:
# <ROOT.RooPlot object ("frame_x_6af2be0") at 0x6af2be0>
# [#1] INFO:Plotting -- RooSimultaneous::plotOn(simPdf) plot on x represents a slice in the index category (sample)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(modelp) slice variable sample was not projected anyway
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_p_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:Plotting -- RooSimultaneous::plotOn(simPdf) plot on x represents a slice in the index category (sample)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(modelp) directly selected PDF components: (px_p)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(modelp) indirectly selected PDF components: (model_p)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(modelp) slice variable sample was not projected anyway
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_p_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
frame2 = x.frame(ROOT.RooFit.Title("Fail sample, {}".format(dgq)))
combData.plotOn(frame2, ROOT.RooFit.Cut("sample==sample::fail"),  ROOT.RooFit.Name("combData"))
simPdf.plotOn(frame2, ROOT.RooFit.Slice(sample, "fail"), 
              ROOT.RooFit.ProjWData(sampleSet, combData),
#               ROOT.RooFit.LineStyle(ROOT.kDashed),
              ROOT.RooFit.LineColor(color),
              ROOT.RooFit.Name("simPdf")
             )

simPdf.plotOn(frame2, 
              ROOT.RooFit.Slice(sample, "fail"), 
              ROOT.RooFit.Components("px_f"), 
              ROOT.RooFit.ProjWData(sampleSet, combData), 
              ROOT.RooFit.LineStyle(ROOT.kDashed),
              ROOT.RooFit.LineColor(color)
             )

# c = ROOT.TCanvas("rf501_simultaneouspdf", "rf501_simultaneouspdf", 1200, 600)
# c.Divide(2,1)
# c.cd(1)
# ROOT.gPad.SetLeftMargin(0.15)
# ROOT.gStyle.SetOptFit(1111)
# frame1.GetYaxis().SetTitleOffset(1.4)
# frame1.SetLineColor(color)
# frame1.GetYaxis().SetRangeUser(0.75*passhist.GetMinimum(), 1.15 * passhist.GetMaximum())
# frame1.Draw()
# c.Update()

# c.cd(2)
# ROOT.gPad.SetLeftMargin(0.15)
# frame2.GetYaxis().SetTitleOffset(1.4)
# frame1.SetLineColor(color)
# frame2.GetYaxis().SetRangeUser(0.75*failhist.GetMinimum(), 1.15 * failhist.GetMaximum())
# frame2.Draw()

# c.SaveAs("simultaneouspdf_{}.png".format(dgq))
# Out:
# <ROOT.RooPlot object ("frame_x_6e0b060") at 0x6e0b060>
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 1.54616e+08 events out of 1.72328e+08 total events
# [#1] INFO:Plotting -- RooSimultaneous::plotOn(simPdf) plot on x represents a slice in the index category (sample)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(modelf) slice variable sample was not projected anyway
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_f_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)
# [#1] INFO:Plotting -- RooSimultaneous::plotOn(simPdf) plot on x represents a slice in the index category (sample)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(modelf) directly selected PDF components: (px_f)
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(modelf) indirectly selected PDF components: (model_f)
# [#1] INFO:Plotting -- RooAbsReal::plotOn(modelf) slice variable sample was not projected anyway
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(px_f_Int[x]) using numeric integrator RooIntegrator1D to calculate Int(x)

# %%
eff = ROOT.RooFormulaVar("eff", "(a_p * f_p) / (a_f * f_f + a_p * f_p) ", ROOT.RooArgList(a_p, f_p, a_f, f_f))

# %%
p = f_p.getVal()
f = f_f.getVal()

dp = f_p.getError()
df = f_f.getError()

a = f+p
da = np.sqrt(df*df + dp*dp)

# %%
deffoeff = np.sqrt( (dp/p)**2 + (da / a)**2 )
deff = deffoeff * eff.getVal()

# %%
print("Efficiency is: {:.4f} +/- {:.4f} %".format(eff.getVal()*100, deff*100))
# Out:
# Efficiency is: 56.3307 +/- 0.3044 %

# %%
dmu = 54.9157 #Data efficiency and uncertainty
dmu_err = 0.6363

gmu = 53.1811 #GJets efficiency and uncertainty
gmu_err = 9.4408

# y = 55.0452 #GJets efficiency and uncertainty with weights
# dy = 10.4371

z = dmu/gmu
dz = z * np.sqrt( (dmu_err/gmu)**2 + (gmu_err/gmu)**2 )

print("Scale Factor is {:.4f} +\- {:.4f}".format(z, dz))
# Out:
# Scale Factor is 1.0326 +\- 0.1837

# %%
np.sqrt((19. / 54.)**2)
# Out:
# 0.35185185185185186

# %%
f_p.getVal()
# Out:
# 0.07215929926254994

# %%
print("Pass Values:")
print("Norm: {}".format(a_p.getVal()))
print("\nGaussian: ")
print("mu = {:.4f} +/- {:.4f}".format(mean_p.getVal(), mean_p.getError()))
print("sigma = {:.4f} +/- {:.4f}".format(sigma_p.getVal(), sigma_p.getError()))


print("\nBackground: ")

if 'data' in dgq:
    print("p0 = {:.2f} +/- {:.2f}".format(a0_p.getVal(), a0_p.getError()))
    print("p1 = {:.2f} +/- {:.2f}".format(a1_p.getVal(), a1_p.getError()))
   
else:
    # Argus
    print("m = {:.2f} +/- {:.2f}".format(m_p.getVal(), m_p.getError()))
    print("m0 = {:.2f} +/- {:.2f}".format(m0_p.getVal(), m0_p.getError()))
    print("c = {:.2f} +/- {:.2f}".format(c_p.getVal(), c_p.getError()))
# Out:
# Pass Values:
# Norm: 19442781.0
#
# Gaussian:
# mu = 0.5376 +/- 0.0001
# sigma = 0.0396 +/- 0.0001
#
# Background:
# p0 = 42.75 +/- 0.11
# p1 = -2.07 +/- 0.00

# %%
print(ss-sw*se)
print(ss+sw*se)
# Out:
# -0.1599
# 0.2401

# %%
print("Fail Values:")
print("Norm: {}".format(a_f.getVal()))
print("\nGaussian")
print("mu = {:.4f} +/- {:.4f}".format(mean_p.getVal(), mean_p.getError()))
print("sigma = {:.4f} +/- {:.4f}".format(sigma_p.getVal(), sigma_p.getError()))

print("\nBackground: ")

if 'data' in dgq:
    print("p0 = {:.2f} +/- {:.2f}".format(a0_f.getVal(), a0_f.getError()))
    print("p1 = {:.3f} +/- {:.3f}".format(a1_f.getVal(), a1_f.getError()))
   
else:
    # Argus
    print("m = {:.2f} +/- {:.2f}".format(m_f.getVal(), m_f.getError()))
    print("m0 = {:.2f} +/- {:.2f}".format(m0_f.getVal(), m0_f.getError()))
    print("c = {:.2f} +/- {:.2f}".format(c_f.getVal(), c_f.getError()))
# Out:
# Fail Values:
# Norm: 169962195.0
#
# Gaussian
# mu = 0.5376 +/- 0.0001
# sigma = 0.0396 +/- 0.0001
#
# Background:
# p0 = 42.75 +/- 0.11
# p1 = -1.911 +/- 0.001

# %%
# pl = p_ext.getParameters(data_pass).contentsString().split(",")
# fl = f_ext.getParameters(data_pass).contentsString().split(",")
# cc = 0
# for ff in fl: 
#     if(ff not in pl): cc += 1
# nparams = len(pl) + cc

if 'data' in dgq:
    nparams = 8
else: 
    nparams = 10
    
# chi2 = frame1.chiSquare("simPdf", "combData" )
# print("Chi2 / ndof is {}".format(chi2))
# chi2 = frame2.chiSquare("simPdf", "combData")
# print("Chi2 / ndof is {}".format(chi2))
    
chi2 = frame1.chiSquare("simPdf", "combData", nparams)
print("Chi2 / ndof is {}".format(chi2))
chi2 = frame2.chiSquare("simPdf", "combData", nparams)
print("Chi2 / ndof is {}".format(chi2))
# Out:
# Chi2 / ndof is 108.827132159
# Chi2 / ndof is 94.6318103146

# %%
hpull = frame1.pullHist("combData", "simPdf")
frame1P = x.frame(ROOT.RooFit.Title(""))
frame1P.addPlotable(hpull, "P")

hpull2 = frame2.pullHist("combData", "simPdf")
frame2P = x.frame(ROOT.RooFit.Title(""))
frame2P.addPlotable(hpull2, "P")

# cA = ROOT.TCanvas("simPull", "simPull", 1200, 600)
cA = ROOT.TCanvas("simPull", "simPull", 600, 600)
# cA.Divide(2,1)

cA.cd(1)

p12 = ROOT.TPad("pad1", "tall",0,0.165,1,1)
p22 = ROOT.TPad("pad2", "short",0,0.0,1.0,0.23)
p22.SetBottomMargin(0.35)
p12.Draw()
p22.Draw()

p12.cd()
ROOT.gPad.SetLeftMargin(0.15)
ROOT.gStyle.SetOptFit(1111)
frame1.SetTitle("Pass Sample, Run 2 Data")
frame1.GetYaxis().SetTitleOffset(1.4)
frame1.SetLineColor(color)
passhist.GetXaxis().SetRangeUser(rlow, rhigh)
frame1.GetYaxis().SetRangeUser(0.75*passhist.GetMinimum(), 1.15 * passhist.GetMaximum())
frame1.GetXaxis().SetLabelOffset(999)
frame1.GetXaxis().SetLabelSize(0)
frame1.Draw()

p22.cd()
ROOT.gPad.SetLeftMargin(0.15)
frame1P.SetTitle(";Mass(GeV);#frac{Data - Fit}{Uncertainty}")
frame1P.GetYaxis().SetLabelSize(0.11)
frame1P.GetXaxis().SetLabelSize(0.15)
frame1P.GetXaxis().SetTitleSize(0.15)
frame1P.GetYaxis().SetTitleOffset(0.3)
frame1P.GetYaxis().SetTitleSize(0.125)
frame1P.Draw()

# L1 = ROOT.TLine(rlow-0.005, 0, rhigh+0.005, 0)
# L1.SetLineColor(12)
# L1.Draw("same")

##############################################################
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: simPull

# %%
# cA.cd(2)

# p12 = ROOT.TPad("pad1", "tall",0,0.165,1,1)
# p22 = ROOT.TPad("pad2", "short",0,0.0,1.0,0.23)
# p22.SetBottomMargin(0.35)
# p12.Draw()
# p22.Draw()

# p12.cd()
# ROOT.gPad.SetLeftMargin(0.15)
# ROOT.gStyle.SetOptFit(1111)
# frame2.GetYaxis().SetTitleOffset(1.4)
# frame2.SetLineColor(color)
# failhist.GetXaxis().SetRangeUser(rlow, rhigh)
# frame2.GetYaxis().SetRangeUser(0.75*failhist.GetMinimum(), 1.15 * failhist.GetMaximum())
# frame2.GetXaxis().SetLabelOffset(999)
# frame2.GetXaxis().SetLabelSize(0)
# frame2.Draw()

# p22.cd()
# ROOT.gPad.SetLeftMargin(0.15)
# frame2P.SetTitle(";Mass(GeV);Data - Fit")
# frame2P.GetYaxis().SetLabelSize(0.11)
# frame2P.GetXaxis().SetLabelSize(0.15)
# frame2P.GetXaxis().SetTitleSize(0.15)
# frame2P.GetYaxis().SetTitleOffset(0.3)
# frame2P.GetYaxis().SetTitleSize(0.15)
# frame2P.Draw()

# L2 = ROOT.TLine(rlow-0.005, 0, rhigh+0.005, 0)
# L2.SetLineColor(12)
# L2.Draw("same")

# %%
gROOT.GetListOfCanvases().Draw()

# %%
print("Eta Pass Rate is: {:.4f} +/- {:.4f} %".format(eff.getVal()*100, deff*100))
print("mu = {:.4f} +/- {:.4f}".format(mean_p.getVal(), mean_p.getError()))
# Out:
# Eta Pass Rate is: 56.3307 +/- 0.3044 %
# mu = 0.5376 +/- 0.0001

# %%
54.35/53.10
# Out:
# 1.0235404896421845

# %%
np.sqrt( (0.43/54.35)**2 + (8.8/53.10)**2  )
# Out:
# 0.16591379076590876
